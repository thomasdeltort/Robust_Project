# %%
import numpy as np
import pickle
import torch

# %%
filename = '../benchmark_dataset_MNIST08/images.pkl'
with open(filename, 'rb') as f:
    # Charger l'objet depuis le fichier
    x = pickle.load(f)
x_np = x.detach().cpu().numpy()

# %%
filename = '../benchmark_dataset_MNIST08/targets.pkl'
with open(filename, 'rb') as f:
    # Charger l'objet depuis le fichier
    y = pickle.load(f)
y_np = y.detach().cpu().numpy()

# %%
nom_fichier_X = '/home/aws_install/robustess_project/SDP-CROWN-Share/datasets/sdp/mnist_benchmark/X_sdp.npy'
nom_fichier_y = '/home/aws_install/robustess_project/SDP-CROWN-Share/datasets/sdp/mnist_benchmark/y_sdp.npy'

np.save(nom_fichier_X, x_np)
np.save(nom_fichier_y, y_np)
